# %% [markdown]
# # Work With Number

# %%
8+1
# Out:
# 9

# %%
8-1
# Out:
# 7

# %%
8/2
# Out:
# 4.0

# %%
8//2
# Out:
# 4

# %%
2**5
# Out:
# 32

# %% [markdown]
# # Bodmas

# %%
10+(3+2)*3
# Out:
# 25

# %%
109%2
# Out:
# 1

# %% [markdown]
# # Work with text

# %%
'welcome1 to jour'
# Out:
# 'welcome1 to jour'

# %%
"welcome1 to jour"
# Out:
# 'welcome1 to jour'

# %%
'''welcome1 to jour'''
# Out:
# 'welcome1 to jour'

# %%
'''welcome1 to
jour'''
# Out:
# 'welcome1 to\njour'

# %% [markdown]
# # python variable

# %%
v1$=8
v1$
#type(v)
# Out:
#   Cell In[34], line 1
#     v1$=8
#       ^
# SyntaxError: invalid syntax

# %%
v1_=8
v1_
# Out:
# 8

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
true=56
true
# Out:
# 56
